# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
    
data = np.loadtxt("mtfuji_data.csv", delimiter=",", skiprows=1)

# %%
#Obtaining elevation data

import pandas as pd
    
path = 'mtfuji_data.csv'

# Read the CSV file using Pandas
data = pd.read_csv(path)

# Display the first few rows of the dataframe to verify it was read correctly
data.head()
# Out:
#    x        lat         lng  elevation  distance
# 0  0  35.134141  139.132082        0.0         0
# 1  1  35.135826  139.129202        0.0       322
# 2  2  35.137510  139.126322        0.0       644
# 3  3  35.139194  139.123441        0.0       966
# 4  4  35.140878  139.120560        0.0      1288

# %%
# Data visualization

points = data[:, :1]
elevations = data[:, 3:4]


plt.plot(points, elevations, "y")

plt.title("Cross section of Mount Fuji")
plt.xlabel("position")
plt.ylabel("Elevation")
plt.grid(True)

# %%
#A function to calculate the slope at a certain point

def gradient(position):
  """"Returns the gradient at position"""
  data = np.loadtxt("mtfuji_data.csv", delimiter=",", skiprows=1)
  elevations = data[:, 3:4]

  try:
    if abs(position) >= elevations.size:
      raise IndexError

    if position == 0:
      return 0
  except IndexError:
    print(f"Position out of bounds {position}>={elevations.size}")
    return
  else:
    y2 = elevations[position]
    y1 = elevations[position -1]

    slope = y2 - y1
    return slope[0]

# %%
gradient(0)
# Out:
# 0

# %%
 #To a function to calculate the destination point

class NegativeError(Exception):
  pass

def destination(point, alpha = 0.2):
  destinPoint = 0
  try:
    destinPoint = (point * alpha) - gradient(point)
    destinPoint = round(destinPoint)

    if destinPoint < 0:
      raise NegativeError
  except NegativeError:
   #print("Destination is not valid")
    destinPoint = abs(destinPoint)
  return destinPoint

# %%
destination(200)
# Out:
# 212

# %%
#Create a function that descends the mountain

def descend(curr_point, learnRate=0.2):
  """Decend Mount Fuji from position"""
  positions = [curr_point]

  #stop when we are on the ground position
  while positions[-1] != 0:
    next_point = destination(positions[-1], learnRate)
    if next_point == None:
      break
    positions.append(next_point)


  return positions


descending= descend(136)
print(descending)
# Out:
# [136, 141, 248, 83, 3, 1, 0]

# %%
# Visualization of the descent process

plt.figure(figsize=(10, 5))

plt.title("Descending Mount Fuji")

plt.xlabel("Moves")
plt.ylabel("Points (m)")
plt.plot(descending, marker="*")
plt.show()

# %%
altitude = [elevations[i] for i in descending]

slopes = [gradient(x) for x in descending]

plt.figure(figsize=(10, 5))
plt.title("Altitude")
plt.plot(altitude, marker="o")
plt.xlabel("Moves")
plt.ylabel("Altitude (m)")
plt.show()


plt.figure(figsize=(10, 5))
plt.title("Slope")
plt.plot(slopes, linestyle="--", marker="x")
plt.xlabel("Moves")
plt.ylabel("Slope")
plt.show()

# %%
# Changing hyperparameters

for x in range(100, 250):
  print(descend(x))
# Out:
# [100, 1, 0]
# [101, 2, 0]
# [102, 2, 0]
# [103, 20, 99, 7, 1, 0]
# [104, 4, 1, 0]
# [105, 6, 5, 1, 0]
# [106, 1, 0]
# [107, 19, 11, 4, 1, 0]
# [108, 5, 1, 0]
# [109, 12, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [110, 3, 1, 0]
# [111, 24, 6, 5, 1, 0]
# [112, 38, 39, 8, 3, 1, 0]
# [113, 31, 108, 5, 1, 0]
# [114, 3, 1, 0]
# [115, 30, 63, 67, 6, 5, 1, 0]
# [116, 44, 9, 40, 8, 3, 1, 0]
# [117, 46, 9, 40, 8, 3, 1, 0]
# [118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [119, 31, 108, 5, 1, 0]
# [120, 12, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [121, 37, 0]
# [122, 43, 9, 40, 8, 3, 1, 0]
# [123, 31, 108, 5, 1, 0]
# [124, 43, 9, 40, 8, 3, 1, 0]
# [125, 78, 12, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [126, 97, 6, 5, 1, 0]
# [127, 95, 7, 1, 0]
# [128, 85, 0]
# [129, 93, 0]
# [130, 111, 24, 6, 5, 1, 0]
# [131, 113, 31, 108, 5, 1, 0]
# [132, 96, 9, 40, 8, 3, 1, 0]
# [133, 116, 44, 9, 40, 8, 3, 1, 0]
# [134, 93, 0]
# [135, 151, 115, 30, 63, 67, 6, 5, 1, 0]
# [136, 141, 248, 83, 3, 1, 0]
# [137, 138, 52, 64, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [138, 52, 64, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [139, 43, 9, 40, 8, 3, 1, 0]
# [140, 125, 78, 12, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [141, 248, 83, 3, 1, 0]
# [142, 205, 8, 3, 1, 0]
# [143, 180, 64, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [144, 184, 39, 8, 3, 1, 0]
# [145, 181, 44, 9, 40, 8, 3, 1, 0]
# [146, 176, 39, 8, 3, 1, 0]
# [147, 146, 176, 39, 8, 3, 1, 0]
# [148, 145, 181, 44, 9, 40, 8, 3, 1, 0]
# [149, 123, 31, 108, 5, 1, 0]
# [150, 125, 78, 12, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [151, 115, 30, 63, 67, 6, 5, 1, 0]
# [152, 128, 85, 0]
# [153, 90, 4, 1, 0]
# [154, 136, 141, 248, 83, 3, 1, 0]
# [155, 82, 1, 0]
# [156, 100, 1, 0]
# [157, 87, 0]
# [158, 64, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [159, 97, 6, 5, 1, 0]
# [160, 73, 1, 0]
# [161, 88, 0]
# [162, 77, 6, 5, 1, 0]
# [163, 83, 3, 1, 0]
# [164, 60, 76, 9, 40, 8, 3, 1, 0]
# [165, 66, 54, 29, 91, 5, 1, 0]
# [166, 47, 9, 40, 8, 3, 1, 0]
# [167, 70, 56, 62, 24, 6, 5, 1, 0]
# [168, 55, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [169, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [170, 55, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [171, 70, 56, 62, 24, 6, 5, 1, 0]
# [172, 63, 67, 6, 5, 1, 0]
# [173, 49, 11, 4, 1, 0]
# [174, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [175, 50, 30, 63, 67, 6, 5, 1, 0]
# [176, 39, 8, 3, 1, 0]
# [177, 41, 8, 3, 1, 0]
# [178, 46, 9, 40, 8, 3, 1, 0]
# [179, 47, 9, 40, 8, 3, 1, 0]
# [180, 64, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [181, 44, 9, 40, 8, 3, 1, 0]
# [182, 51, 39, 8, 3, 1, 0]
# [183, 47, 9, 40, 8, 3, 1, 0]
# [184, 39, 8, 3, 1, 0]
# [185, 99, 7, 1, 0]
# [186, 72, 21, 26, 146, 176, 39, 8, 3, 1, 0]
# [187, 80, 14, 156, 100, 1, 0]
# [188, 7, 1, 0]
# [189, 174, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [190, 196, 67, 6, 5, 1, 0]
# [191, 122, 43, 9, 40, 8, 3, 1, 0]
# [192, 112, 38, 39, 8, 3, 1, 0]
# [193, 39, 8, 3, 1, 0]
# [194, 39, 8, 3, 1, 0]
# [195, 82, 1, 0]
# [196, 67, 6, 5, 1, 0]
# [197, 10, 115, 30, 63, 67, 6, 5, 1, 0]
# [198, 205, 8, 3, 1, 0]
# [199, 135, 151, 115, 30, 63, 67, 6, 5, 1, 0]
# [200, 212, 102, 2, 0]
# [201, 147, 146, 176, 39, 8, 3, 1, 0]
# [202, 100, 1, 0]
# [203, 95, 7, 1, 0]
# [204, 44, 9, 40, 8, 3, 1, 0]
# [205, 8, 3, 1, 0]
# [206, 39, 8, 3, 1, 0]
# [207, 33, 21, 26, 146, 176, 39, 8, 3, 1, 0]
# [208, 193, 39, 8, 3, 1, 0]
# [209, 94, 10, 115, 30, 63, 67, 6, 5, 1, 0]
# [210, 56, 62, 24, 6, 5, 1, 0]
# [211, 94, 10, 115, 30, 63, 67, 6, 5, 1, 0]
# [212, 102, 2, 0]
# [213, 44, 9, 40, 8, 3, 1, 0]
# [214, 109, 12, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [215, 164, 60, 76, 9, 40, 8, 3, 1, 0]
# [216, 57, 98, 4, 1, 0]
# [217, 81, 6, 5, 1, 0]
# [218, 90, 4, 1, 0]
# [219, 51, 39, 8, 3, 1, 0]
# [220, 31, 108, 5, 1, 0]
# [221, 76, 9, 40, 8, 3, 1, 0]
# [222, 183, 47, 9, 40, 8, 3, 1, 0]
# [223, 130, 111, 24, 6, 5, 1, 0]
# [224, 71, 64, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [225, 25, 59, 14, 156, 100, 1, 0]
# [226, 108, 5, 1, 0]
# [227, 17, 120, 12, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [228, 63, 67, 6, 5, 1, 0]
# [229, 29, 91, 5, 1, 0]
# [230, 139, 43, 9, 40, 8, 3, 1, 0]
# [231, 124, 43, 9, 40, 8, 3, 1, 0]
# [232, 33, 21, 26, 146, 176, 39, 8, 3, 1, 0]
# [233, 107, 19, 11, 4, 1, 0]
# [234, 131, 113, 31, 108, 5, 1, 0]
# [235, 64, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [236, 8, 3, 1, 0]
# [237, 61, 120, 12, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [238, 20, 99, 7, 1, 0]
# [239, 6, 5, 1, 0]
# [240, 37, 0]
# [241, 119, 31, 108, 5, 1, 0]
# [242, 16, 5, 1, 0]
# [243, 55, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [244, 2, 0]
# [245, 10, 115, 30, 63, 67, 6, 5, 1, 0]
# [246, 158, 64, 48, 118, 53, 116, 44, 9, 40, 8, 3, 1, 0]
# [247, 57, 98, 4, 1, 0]
# [248, 83, 3, 1, 0]
# [249, 45, 9, 40, 8, 3, 1, 0]

# %%
# Visualization of the descent process for each initial value

def display(value):
  plt.figure(figsize=(10, 5))
  plt.title("Descending Mount Fuji")
  plt.xlabel("Moves")
  plt.ylabel("Points (m)")
  plt.plot(value, marker="*")
  plt.show()

  altitude = [elevations[i] for i in value]

  slopes = [gradient(x) for x in value]

  plt.figure(figsize=(10, 5))
  plt.title("Altitude")
  plt.plot(altitude, marker="o")
  plt.xlabel("Moves")
  plt.ylabel("Altitude (m)")
  plt.show()


  plt.figure(figsize=(10, 5))
  plt.title("Slope")
  plt.plot(slopes, linestyle="--", marker="x")
  plt.xlabel("Moves")
  plt.ylabel("Slope")
  plt.show()
     
        
display(descend(200)) 

display(descend(142))

# %%
#Using 136 as specified in problem 4
descending = descend(136, 0.4)

display(descending)
