# %%
import numpy as np
from sklearn.datasets import load_iris
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Problem 1:Data acquisition

# %%
data = load_iris(as_frame=True)

x = pd.DataFrame(data["data"])

y = pd.DataFrame(data["target"])

y.columns= ["Species"]

print(x.head(), y.head(),sep="\n")
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# Problem 2:Combining data

# %%
df = pd.concat([x, y], axis=1)

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# Question 3: Checking the data

# %%
#4th sample from the beginning
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Species            150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %% [markdown]
# Problem 4:Investigation of the iris dataset itself

# %%
#4th sample from the beginning
df.info()

#total number of samples for each label
df.count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Species            150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB
# sepal length (cm)    150
# sepal width (cm)     150
# petal length (cm)    150
# petal width (cm)     150
# Species              150
# dtype: int64

# %%
#Check if there is a missing value in the feature quantity

df.isnull().sum()

df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     Species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df.value_counts()
# Out:
# sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  Species
# 5.8                2.7               5.1                1.9               2          2
# 6.2                2.2               4.5                1.5               1          1
#                    2.9               4.3                1.3               1          1
#                    3.4               5.4                2.3               2          1
# 6.3                2.3               4.4                1.3               1          1
#                                                                                     ..
# 5.4                3.9               1.3                0.4               0          1
#                                      1.7                0.4               0          1
# 5.5                2.3               4.0                1.3               1          1
#                    2.4               3.7                1.0               1          1
# 7.9                3.8               6.4                2.0               2          1
# Name: count, Length: 149, dtype: int64

# %% [markdown]
# Problem 5:Extract the necessary data

# %%
#Extract the sepal_width column in two different ways
sepal_width = df["sepal width (cm)"]
print(sepal_width.head())

sepal_width = df.loc[:, "sepal width (cm)"]

print(sepal_width.head())

#Extract the 50th to 99th data​
df.iloc[50:100]
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# Name: sepal width (cm), dtype: float64
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# Name: sepal width (cm), dtype: float64
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
# 55                5.7               2.8                4.5               1.3
# 56                6.3               3.3                4.7               1.6
# 57                4.9               2.4                3.3               1.0
# 58                6.6               2.9                4.6               1.3
# 59                5.2               2.7                3.9               1.4
# 60                5.0               2.0                3.5               1.0
# 61                5.9               3.0                4.2               1.5
# 62                6.0               2.2                4.0               1.0
# 63                6.1               2.9                4.7               1.4
# 64                5.6               2.9                3.6               1.3
# 65                6.7               3.1                4.4               1.4
# 66                5.6               3.0                4.5               1.5
# 67                5.8               2.7                4.1               1.0
# 68                6.2               2.2                4.5               1.5
# 69                5.6               2.5                3.9               1.1
# 70                5.9               3.2                4.8               1.8
# 71                6.1               2.8                4.0               1.3
# 72                6.3               2.5                4.9               1.5
# 73                6.1               2.8                4.7               1.2
# 74                6.4               2.9                4.3               1.3
# 75                6.6               3.0                4.4               1.4
# 76                6.8               2.8                4.8               1.4
# 77                6.7               3.0                5.0               1.7
# 78                6.0               2.9                4.5               1.5
# 79                5.7               2.6                3.5               1.0
# 80                5.5               2.4                3.8               1.1
# 81                5.5               2.4                3.7               1.0
# 82                5.8               2.7                3.9               1.2
# 83                6.0               2.7                5.1               1.6
# 84                5.4               3.0                4.5               1.5
# 85                6.0               3.4                4.5               1.6
# 86                6.7               3.1                4.7               1.5
# 87                6.3               2.3                4.4               1.3
# 88                5.6               3.0                4.1               1.3
# 89                5.5               2.5                4.0               1.3
# 90                5.5               2.6                4.4               1.2
# 91                6.1               3.0                4.6               1.4
# 92                5.8               2.6                4.0               1.2
# 93                5.0               2.3                3.3               1.0
# 94                5.6               2.7                4.2               1.3
# 95                5.7               3.0                4.2               1.2
# 96                5.7               2.9                4.2               1.3
# 97                6.2               2.9                4.3               1.3
# 98                5.1               2.5                3.0               1.1
# 99                5.7               2.8                4.1               1.3
#
#     Species
# 50        1
# 51        1
# 52        1
# 53        1
# 54        1
# 55        1
# 56        1
# 57        1
# 58        1
# 59        1
# 60        1
# 61        1
# 62        1
# 63        1
# 64        1
# 65        1
# 66        1
# 67        1
# 68        1
# 69        1
# 70        1
# 71        1
# 72        1
# 73        1
# 74        1
# 75        1
# 76        1
# 77        1
# 78        1
# 79        1
# 80        1
# 81        1
# 82        1
# 83        1
# 84        1
# 85        1
# 86        1
# 87        1
# 88        1
# 89        1
# 90        1
# 91        1
# 92        1
# 93        1
# 94        1
# 95        1
# 96        1
# 97        1
# 98        1
# 99        1

# %%
#Extract the50th to 99th data of the petal_length column

df.loc[50:100, "petal length (cm)"]
# Out:
# 50     4.7
# 51     4.5
# 52     4.9
# 53     4.0
# 54     4.6
# 55     4.5
# 56     4.7
# 57     3.3
# 58     4.6
# 59     3.9
# 60     3.5
# 61     4.2
# 62     4.0
# 63     4.7
# 64     3.6
# 65     4.4
# 66     4.5
# 67     4.1
# 68     4.5
# 69     3.9
# 70     4.8
# 71     4.0
# 72     4.9
# 73     4.7
# 74     4.3
# 75     4.4
# 76     4.8
# 77     5.0
# 78     4.5
# 79     3.5
# 80     3.8
# 81     3.7
# 82     3.9
# 83     5.1
# 84     4.5
# 85     4.5
# 86     4.7
# 87     4.4
# 88     4.1
# 89     4.0
# 90     4.4
# 91     4.6
# 92     4.0
# 93     3.3
# 94     4.2
# 95     4.2
# 96     4.2
# 97     4.3
# 98     3.0
# 99     4.1
# 100    6.0
# Name: petal length (cm), dtype: float64

# %%
# Extract data with a petal_width value of 0.2
df[df["petal width (cm)"]==0.2]
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# 7                 5.0               3.4                1.5               0.2
# 8                 4.4               2.9                1.4               0.2
# 10                5.4               3.7                1.5               0.2
# 11                4.8               3.4                1.6               0.2
# 14                5.8               4.0                1.2               0.2
# 20                5.4               3.4                1.7               0.2
# 22                4.6               3.6                1.0               0.2
# 24                4.8               3.4                1.9               0.2
# 25                5.0               3.0                1.6               0.2
# 27                5.2               3.5                1.5               0.2
# 28                5.2               3.4                1.4               0.2
# 29                4.7               3.2                1.6               0.2
# 30                4.8               3.1                1.6               0.2
# 33                5.5               4.2                1.4               0.2
# 34                4.9               3.1                1.5               0.2
# 35                5.0               3.2                1.2               0.2
# 36                5.5               3.5                1.3               0.2
# 38                4.4               3.0                1.3               0.2
# 39                5.1               3.4                1.5               0.2
# 42                4.4               3.2                1.3               0.2
# 46                5.1               3.8                1.6               0.2
# 47                4.6               3.2                1.4               0.2
# 48                5.3               3.7                1.5               0.2
# 49                5.0               3.3                1.4               0.2
#
#     Species
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# 7         0
# 8         0
# 10        0
# 11        0
# 14        0
# 20        0
# 22        0
# 24        0
# 25        0
# 27        0
# 28        0
# 29        0
# 30        0
# 33        0
# 34        0
# 35        0
# 36        0
# 38        0
# 39        0
# 42        0
# 46        0
# 47        0
# 48        0
# 49        0

# %% [markdown]
# Question 6 :Creating a diagram

# %%
#draw a pie chart of the number of samples per label (while showing percentages)

species_info = df.groupby(["Species"]).count()
labels = data.target_names

for key in species_info.keys():
  fig, ax = plt.subplots(figsize=(5, 5))
  ax.set_title(key)
  ax.pie(species_info[key], autopct= lambda pct: f"{pct :.1f}%")
  fig.legend(labels)
plt.show()

# %%
#Select features one by one and visualize the distribution of data for each label using a box plot
features = df.keys()
species = data.target_names
for feature in features[:-1]:
  feat = []
  for i in range(species.size):
    feat.append(df[df['Species']==i][feature])
  fig, ax = plt.subplots(figsize=(7, 7))
  ax.boxplot(feat)
  ax.set_title(feature)
  ax.grid()
  fig.legend(species)
plt.show()

# %%
#Select features one after another,then visualize the distribution of data for each label using a violin plot
features = df.keys()
species = data.target_names
for feature in features[:-1]:
  feat = []
  for i in range(species.size):
    feat.append(df[df['Species']==i][feature])
  fig, ax = plt.subplots(figsize=(7, 7))
  ax.violinplot(feat)
  ax.set_title(feature)
  ax.grid()
  fig.legend(species)
plt.show()

# %% [markdown]
# Problem 7: Checking the relationship between features

# %%
#get a list of all columns excluding the last
features = df.keys()[:-1]

#get a list of the species of flowers available
species = data.target_names

#for each feature, group by species
grouped_iris = {}

for feature in features:
  grouped_iris[feature] = []
  for specie in range(species.size):
    grouped_iris[feature].append(df[df["Species"] == specie][feature])

# %%
""""create scatter plots of all combinations (six), such as choosing two from four features, color-coded by type"""
for x in range(4):
  for i in range(4):
    if x == i:
      continue
    #print((x, (x-i) % 4))
index = 0
keys = list(grouped_iris.keys())

for i in range(len(keys)):
  x, y = "", ""
  for a in range(len(keys)):
    if i == a:
      continue
    x = keys[i]
    y = keys[a]
    fig = plt.figure(figsize=(10, 6))
    ax = fig.add_subplot(111)
    ax.scatter(grouped_iris[x][0], grouped_iris[y][0], c="r")
    ax.scatter(grouped_iris[x][1], grouped_iris[y][1], c="b")
    ax.scatter(grouped_iris[x][2], grouped_iris[y][2], c="y")
    ax.set_title(f"A graph of {x} VS {y}")
    plt.xlabel(x)
    plt.ylabel(y)
    ax.legend(species)
    ax.grid(True)

# %%
#Create a scatterplot matrix that displays all combinations of features at once

sns.pairplot(df, hue="Species")
# Out:
# C:\Users\cbt04\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Create a correlation coefficient matrix for 4 features
sample = data["data"]

correlation_matrix = sample.corr()
correlation_matrix
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %%
#create heat map of the correlation coefficient matrix (1)

sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %% [markdown]
# Problem 8: Explanation of the results of visualized graphs and tables

# %% [markdown]
# There are three species of flowers; 'setosa', 'versicolor' and 'virginica'
# These flowers were compared by taking the dimensino of the petal and sepal
# From the data collected, it was observed that the virginica is the largest flower in the iris family.It has the largest petal length and width and its sepal length and width  in the family.
# also, it was observed that the setosa flowers have the potential to grow as big as the virginica flowers in some case, why this happens is unclear based on the present data.
# However, these is the order of flowersm in respect of heirarchy in size
#
# a.Virginica
#
# b.Versicolo
#
# c.Setosa
